# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_regression

# %%
# Generate a systhetic dataset
X, y = make_regression(n_samples= 200, n_features=1, noise=20, random_state=42)

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
#Fit regresssion model
model = LinearRegression()
model.fit(X_train, y_train)

# predict the values using the test set
y_pred = model.predict(X_test)

# %%
#residulas
residuals = y_test - y_pred

#Plot the residulas
plt.scatter(X_test, residuals)
plt.axhline(0, color='r', linestyle='--')
plt.xlabel('X_test')
plt.ylabel('Residuals')
# Out:
# Text(0, 0.5, 'Residuals')

# %%
#Plotting data and regression
plt.figure(figsize=(5,5))
sns.scatterplot(x=X_test.flatten(), y=y_test, label="Current", color='blue')
sns.scatterplot(x=X_test.flatten(), y=y_test, label="predicted", color='red')
plt.xlabel('X_test: Independent variable')
plt.ylabel('Y_test: Dependent variable')
plt.title('Regression Plot')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Load the wine dataset
wine = load_wine(as_frame=True)
X = wine.data
y = wine.target

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Fit a linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model (optional)


mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 0.05978606241082454
# R-squared: 0.9007762333580168

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a scatter plot of actual vs predicted values
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred)
plt.xlabel("Actual Wine Class")
plt.ylabel("Predicted Wine Class")
plt.title("Actual vs Predicted Wine Class")
plt.show()
